# %%
import numpy as np
import pandas as pd
#import dataprep.eda as dp  #Paquete de la universidad simon Fraser
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as ss
import plotly.express as px
import plotly.graph_objects as go
from ipywidgets import interact, Layout
import ipywidgets as widgets

# %% [markdown]
# ##### Agregar la base de datos

# %%
DF=pd.read_csv('C:/Users/ASUS/Desktop/MINE_V/Semestre 2/Seminario de Programacion/Proyecto Dash/Water Quality Testing.csv')

# %% [markdown]
# #### Estadística descriptiva de las variables

# %%
DF.describe(include='all')
# Out:
#         Sample ID          pH  Temperature   Turbidity  Dissolved Oxygen  \
# count  500.000000  500.000000   500.000000  500.000000        500.000000
# mean   250.500000    7.161140    22.054400    4.169400          8.382200
# std    144.481833    0.107531     0.903123    0.397492          0.822396
# min      1.000000    6.830000    20.300000    3.100000          6.000000
# 25%    125.750000    7.080000    21.200000    3.800000          7.800000
# 50%    250.500000    7.160000    22.200000    4.200000          8.400000
# 75%    375.250000    7.250000    22.900000    4.500000          9.100000
# max    500.000000    7.480000    23.600000    5.100000          9.900000
#
#        Conductivity
# count    500.000000
# mean     344.362000
# std       13.038672
# min      316.000000
# 25%      333.000000
# 50%      344.000000
# 75%      355.000000
# max      370.000000

# %% [markdown]
# ## Histograma y gráfico de desnsidad del pH

# %%
sns.histplot(DF['pH'],kde=True,color="skyblue")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\ASUS\Desktop\MINE_V\Semestre 2\Seminario de Programacion\Proyecto Dash\DASH.ipynb Cell 7 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ASUS/Desktop/MINE_V/Semestre%202/Seminario%20de%20Programacion/Proyecto%20Dash/DASH.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> sns.histplot(DF['pH'],kde=True,color="skyblue")
#
# NameError: name 'sns' is not defined

# %% [markdown]
# ## Diagrama de dispersón del pH con la Conductividad

# %% [markdown]
# #### Forma 1

# %%
sns.relplot(x="pH", y="Conductivity", data=DF)

# %% [markdown]
# #### Forma 2 (Dispersión junto al histograma de cada variable y su linea de tendencia)

# %%
sns.jointplot(data=DF, x="pH", y="Conductivity", kind="reg")
